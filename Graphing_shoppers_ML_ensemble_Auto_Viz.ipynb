# %% [markdown]
# # AutoViz no longer displays plots automatically. You must perform %matplotlib inline just before you run AutoViz on your data.

# %%
# pip install autoviz
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.41-py3-none-any.whl (62 kB)
# Collecting panel~=0.12.6
#   Downloading panel-0.12.7-py2.py3-none-any.whl (12.9 MB)
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp38-cp38-win_amd64.whl (152 kB)
# Collecting fsspec>=0.8.3
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.1-cp38-cp38-win_amd64.whl (7.3 MB)
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp38-cp38-win_amd64.whl (9.1 MB)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
# Collecting holoviews>=1.14.6
#   Downloading holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
# Collecting bokeh>=2.4.2
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Collecting seaborn>=0.11.1
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting matplotlib>=3.3.3
#   Downloading matplotlib-3.5.2-cp38-cp38-win_amd64.whl (7.2 MB)
# Collecting hvplot>=0.7.3
#   Downloading hvplot-0.8.0-py2.py3-none-any.whl (3.1 MB)
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
# Collecting xgboost>=0.82
#   Using cached xgboost-1.6.1-py3-none-win_amd64.whl (125.4 MB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from autoviz) (4.1.1)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipython in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from autoviz) (8.3.0)
# Collecting numpy
#   Downloading numpy-1.23.0-cp38-cp38-win_amd64.whl (14.7 MB)
# Collecting pyamg
#   Downloading pyamg-4.2.3-cp38-cp38-win_amd64.whl (1.4 MB)
# Collecting pandas
#   Downloading pandas-1.4.3-cp38-cp38-win_amd64.whl (10.6 MB)
# Requirement already satisfied: tornado>=5.1 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from bokeh>=2.4.2->autoviz) (6.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from bokeh>=2.4.2->autoviz) (21.3)
# Collecting PyYAML>=3.10
#   Downloading PyYAML-6.0-cp38-cp38-win_amd64.whl (155 kB)
# Collecting pillow>=7.1.0
#   Downloading Pillow-9.1.1-cp38-cp38-win_amd64.whl (3.3 MB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from bokeh>=2.4.2->autoviz) (3.0.3)
# Collecting colorcet
#   Downloading colorcet-3.0.0-py2.py3-none-any.whl (1.6 MB)
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.2.0-py2.py3-none-any.whl (42 kB)
# Collecting param<2.0,>=1.9.3
#   Downloading param-1.12.2-py2.py3-none-any.whl (86 kB)
# Collecting pyct>=0.4.4
#   Downloading pyct-0.4.8-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from Jinja2>=2.9->bokeh>=2.4.2->autoviz) (2.1.1)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.3-cp38-cp38-win_amd64.whl (55 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from matplotlib>=3.3.3->autoviz) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Collecting setuptools<61,>=42
#   Downloading setuptools-60.10.0-py3-none-any.whl (1.1 MB)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
# Requirement already satisfied: bleach in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from panel~=0.12.6->autoviz) (4.1.0)
# Collecting markdown
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
# Collecting tqdm>=4.48.0
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: six>=1.5 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->autoviz) (1.16.0)
# Collecting scipy>=1.0
#   Downloading scipy-1.8.1-cp38-cp38-win_amd64.whl (36.9 MB)
# Requirement already satisfied: colorama in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from tqdm>=4.48.0->panel~=0.12.6->autoviz) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from bleach->panel~=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipython->autoviz) (0.18.1)
# Requirement already satisfied: decorator in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipython->autoviz) (2.11.2)
# Requirement already satisfied: matplotlib-inline in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipython->autoviz) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipython->autoviz) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: backcall in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jedi>=0.16->ipython->autoviz) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz) (0.2.5)
# Collecting jupyter-console
#   Downloading jupyter_console-6.4.4-py3-none-any.whl (22 kB)
# Requirement already satisfied: nbconvert in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jupyter->autoviz) (6.4.4)
# Collecting ipywidgets
#   Downloading ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
# Collecting qtconsole
#   Downloading qtconsole-5.3.1-py3-none-any.whl (120 kB)
# Requirement already satisfied: ipykernel in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jupyter->autoviz) (6.9.1)
# Requirement already satisfied: notebook in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jupyter->autoviz) (6.4.11)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipykernel->jupyter->autoviz) (7.2.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipykernel->jupyter->autoviz) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipykernel->jupyter->autoviz) (1.5.5)
# Requirement already satisfied: entrypoints in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz) (0.4)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz) (4.10.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client<8.0->ipykernel->jupyter->autoviz) (302)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from ipywidgets->jupyter->autoviz) (0.2.0)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from notebook->jupyter->autoviz) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from notebook->jupyter->autoviz) (0.13.1)
# Requirement already satisfied: nbformat in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from notebook->jupyter->autoviz) (5.3.0)
# Requirement already satisfied: argon2-cffi in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from notebook->jupyter->autoviz) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from nbconvert->jupyter->autoviz) (0.8.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: defusedxml in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: testpath in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from nbconvert->jupyter->autoviz) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from nbconvert->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from nbconvert->jupyter->autoviz) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from nbconvert->jupyter->autoviz) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from nbconvert->jupyter->autoviz) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from nbformat->notebook->jupyter->autoviz) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from nbformat->notebook->jupyter->autoviz) (2.15.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->autoviz) (5.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->autoviz) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->autoviz) (0.18.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook->jupyter->autoviz) (3.8.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->autoviz) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from argon2-cffi->notebook->jupyter->autoviz) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz) (2.3.1)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.6.2-cp38-cp38-win_amd64.whl (262 kB)
# Collecting joblib
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.1.0-py3-none-any.whl (68 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from requests->panel~=0.12.6->autoviz) (2022.6.15)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: asttokens in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from stack-data->ipython->autoviz) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from stack-data->ipython->autoviz) (0.2.2)
# Requirement already satisfied: executing in c:\users\pablo dad\.conda\envs\autoviz\lib\site-packages (from stack-data->ipython->autoviz) (0.8.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=1056008254ffb180f74337ec685ad98a9aa7e7e4586b18bb9fa38a058f7c0481
#   Stored in directory: c:\users\pablo dad\appdata\local\pip\cache\wheels\5e\8c\80\c3646df8201ba6f5070297fe3779a4b70265d0bfd961c15302
# Successfully built emoji
# Installing collected packages: setuptools, urllib3, PyYAML, pillow, param, numpy, importlib-metadata, idna, charset-normalizer, tqdm, requests, pyviz-comms, pytz, pyct, markdown, bokeh, widgetsnbextension, regex, qtpy, panel, pandas, kiwisolver, jupyterlab-widgets, joblib, fonttools, cycler, colorcet, click, threadpoolctl, scipy, qtconsole, patsy, nltk, matplotlib, jupyter-console, ipywidgets, holoviews, xlrd, xgboost, wordcloud, textblob, statsmodels, seaborn, scikit-learn, pyamg, jupyter, hvplot, fsspec, emoji, autoviz
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 61.2.0
#     Uninstalling setuptools-61.2.0:
#       Successfully uninstalled setuptools-61.2.0
# Successfully installed PyYAML-6.0 autoviz-0.1.41 bokeh-2.4.3 charset-normalizer-2.1.0 click-8.1.3 colorcet-3.0.0 cycler-0.11.0 emoji-1.7.0 fonttools-4.33.3 fsspec-2022.5.0 holoviews-1.14.9 hvplot-0.8.0 idna-3.3 importlib-metadata-4.12.0 ipywidgets-7.7.1 joblib-1.1.0 jupyter-1.0.0 jupyter-console-6.4.4 jupyterlab-widgets-1.1.1 kiwisolver-1.4.3 markdown-3.3.7 matplotlib-3.5.2 nltk-3.7 numpy-1.23.0 pandas-1.4.3 panel-0.12.7 param-1.12.2 patsy-0.5.2 pillow-9.1.1 pyamg-4.2.3 pyct-0.4.8 pytz-2022.1 pyviz-comms-2.2.0 qtconsole-5.3.1 qtpy-2.1.0 regex-2022.6.2 requests-2.28.1 scikit-learn-1.1.1 scipy-1.8.1 seaborn-0.11.2 setuptools-60.10.0 statsmodels-0.13.2 textblob-0.17.1 threadpoolctl-3.1.0 tqdm-4.64.0 urllib3-1.26.9 widgetsnbextension-3.6.1 wordcloud-1.8.2.2 xgboost-1.6.1 xlrd-2.0.1

# %%
import pandas as pd
import numpy as np

# %% [raw]
# ###########  import Autoviz_Class ################

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %% [raw]
# ###########  set up the data #####################

# %% [markdown]
# ## Arguments
#
# * `filename` - Make sure that you give filename as empty string ("") if there is no filename associated with this data and you want to use a dataframe, then use dfte to give the name of the dataframe. Otherwise, fill in the file name and leave dfte as empty string. Only one of these two is needed to load the data set.
# * `sep` - this is the separator in the file. It can be comma, semi-colon or tab or any value that you see in your file that separates each column.
# * `depVar` - target variable in your dataset. You can leave it as empty string if you don't have a target variable in your data.
# * `dfte` - this is the input dataframe in case you want to load a pandas dataframe to plot charts. In that case, leave filename as an empty string.
# * `header` - the row number of the header row in your file. If it is the first row, then this must be zero.
# * `verbose` - it has 3 acceptable values: 0, 1 or 2.
#         `0` you get all charts but limited info.
#         `1` you get all charts and more info.
#         `2` you will not see any charts but they will be quietly generated and save in your local current directory
#             under the AutoViz_Plots directory which will be created. Make sure you delete this folder periodically,
#             otherwise, you will have lots of charts saved here if you used verbose=2 option a lot.
# * `lowess` - Possible values `True` or `False` this option is very nice for small datasets where you can see regression lines for each pair of continuous variable against the target variable. Don't use this for large data sets (that is over 100,000 rows)
# * `chart_format` - this can be 'svg', 'png', 'jpg' or 'bokeh' or 'server' or 'html'. You will get charts generated (inline with verbose=0 or 1 option). Instead you can silently save them in multiple formats if you used verbose=2 option. The latter options are useful for interactive charts.
# * `max_rows_analyzed` - limits the max number of rows that is used to display charts. If you have a very large data set with millions of rows, then use this option to limit the amount of time it takes to generate charts. We will take a statistically valid sample.
# * `max_cols_analyzed` - limits the number of continuous vars that can be analyzed
# * `save_plot_dir` - directory you want the plots to be saved. Default is None which means it is saved under the current directory under a sub-folder named AutoViz_Plots. If the save_plot_dir does not exist, it creates it.

# %% [markdown]
# ### verbose option
#
# * if 0, display minimal information but displays charts on your notebook
# * if 1, print extra information on the notebook and also display charts
# * if 2, will not display any charts, it will simply save them in your local machine under AutoViz_Plots directory under your current working folder.
#
# ### chart_format option
#
# * if 'svg','jpg' or 'png', displays all charts or saves them depending on verbose option.
# * if 'bokeh', plots interactive charts using Bokeh on your Jupyter Notebook
# * if 'server', will display charts on your browser with one chart type in each tab
# * if 'html', will create bokeh interactive charts and silently save them under AutoViz_Plots directory or any directory you specify in the save_plot_dir setting.

# %%
# filename = 'https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/MASS/Boston.csv'
# filename = 'Boston.csv'
filename = 'online_shoppers_intention.csv'
# depVar = 'medv'
# verbose = 2 means that charts will be saved in local machine repository under the folder AutoViz_Plots
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="Revenue",
    dfte=None,
    header=0,
    verbose=1,
    lowess=True,
    chart_format="server",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
    save_plot_dir=None
)
# Out:
# Shape of your Data Set loaded: (12330, 18)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  7
#     Number of Integer-Categorical Columns =  7
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     17 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Binary_Classification problem #####################
# Data Set Shape: 12330 rows, 18 cols
# Data Set columns info:
# * Administrative: 0 nulls, 27 unique vals, most common: {0: 5768, 1: 1354}
# * Administrative_Duration: 0 nulls, 3335 unique vals, most common: {0.0: 5903, 4.0: 56}
# * Informational: 0 nulls, 17 unique vals, most common: {0: 9699, 1: 1041}
# * Informational_Duration: 0 nulls, 1258 unique vals, most common: {0.0: 9925, 9.0: 33}
# * ProductRelated: 0 nulls, 311 unique vals, most common: {1: 622, 2: 465}
# * ProductRelated_Duration: 0 nulls, 9551 unique vals, most common: {0.0: 755, 17.0: 21}
# * BounceRates: 0 nulls, 1872 unique vals, most common: {0.0: 5518, 0.2: 700}
# * ExitRates: 0 nulls, 4777 unique vals, most common: {0.2: 710, 0.1: 338}
# * PageValues: 0 nulls, 2704 unique vals, most common: {0.0: 9600, 53.988: 6}
# * SpecialDay: 0 nulls, 6 unique vals, most common: {0.0: 11079, 0.6: 351}
# * Month: 0 nulls, 10 unique vals, most common: {'May': 3364, 'Nov': 2998}
# * OperatingSystems: 0 nulls, 8 unique vals, most common: {2: 6601, 1: 2585}
# * Browser: 0 nulls, 13 unique vals, most common: {2: 7961, 1: 2462}
# * Region: 0 nulls, 9 unique vals, most common: {1: 4780, 3: 2403}
# * TrafficType: 0 nulls, 20 unique vals, most common: {2: 3913, 1: 2451}
# * VisitorType: 0 nulls, 3 unique vals, most common: {'Returning_Visitor': 10551, 'New_Visitor': 1694}
# * Weekend: 0 nulls, 2 unique vals, most common: {False: 9462, True: 2868}
# * Revenue: 0 nulls, 2 unique vals, most common: {0: 10422, 1: 1908}
# --------------------------------------------------------------------
#    Columns to delete:
# '   []'
#    Boolean variables %s
# "   ['Weekend']"
#    Categorical variables %s
# ("   ['Month', 'VisitorType', 'Administrative', 'Informational', "
#  "'ProductRelated', 'OperatingSystems', 'Browser', 'Region', 'TrafficType', "
#  "'Weekend']")
#    Continuous variables %s
# ("   ['Administrative_Duration', 'Informational_Duration', "
#  "'ProductRelated_Duration', 'BounceRates', 'ExitRates', 'PageValues', "
#  "'SpecialDay']")
#    Discrete string variables %s
# '   []'
#    Date and time variables %s
# '   []'
#    ID variables %s
# '   []'
#    Target variable %s
# '   Revenue'
# scatterplots can be found in URL below:
# Launching server at http://localhost:60592
# pair_scatters can be found in URL below:
# Launching server at http://localhost:60593
# distplots can be found in URL below:
# Launching server at http://localhost:60594
# distplots can be found in URL below:
# Launching server at http://localhost:60595
# kde_plots can be found in URL below:
# Launching server at http://localhost:60596
# violinplots can be found in URL below:
# Launching server at http://localhost:60597
# No date vars could be found in data set
# heatmaps can be found in URL below:
# Launching server at http://localhost:60598
# cat_var_plots can be found in URL below:
# Launching server at http://localhost:60599
# Time to run AutoViz (in seconds) = 0

# %% [raw]
# ###########  Create the autoviz_class #############

# %%
AV = AutoViz_Class()

# %% [raw]
# ###########  do %matplotlib inline now ############

# %%
# %matplotlib inline

# %% [raw]
# ###########  Now run Autoviz ######################

# %%
_ = AV.AutoViz(filename)
# Out:
# Shape of your Data Set loaded: (12330, 18)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     18 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# Number of All Scatter Plots = 28
# Time to run AutoViz = 21 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
